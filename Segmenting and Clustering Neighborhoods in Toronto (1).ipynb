# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
#
# ### All the 3 tasks of web scraping, cleaning and clustering are implemented in the same notebook for the ease of evaluation.
#
# ## 1. Getting data from Wikipedia

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

res = requests.get(url)
wikipedia_html = res.text
soup = BeautifulSoup(wikipedia_html, "html.parser")

table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# %% [markdown]
# ### Displaying DF

# %%
import pandas as pd
df=pd.DataFrame(table_contents)

df.head()

## 2. Reading geospatial coordinates

csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv'
df_geo = pd.read_csv(csv_path)

df_geo.head()


df = df.sort_values(by="PostalCode", ignore_index=True)
df.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# ### Merging the dataframes

# %%
#Obtain latitude and longitude coordinates
latitude=df_geo["Latitude"]
longitude = df_geo["Longitude"]

#Merge to dataframe
df["Latitude"] = latitude
df["Longitude"] = longitude

df.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ## 3. Creating Map

# %%
! pip install folium==0.5.0
import folium

toronto_df = df[df['Borough'].isin(['Central Toronto', 'Downtown Toronto','West Toronto', 'East YorkEast Toronto'])].reset_index(drop=True)
toronto_df.head()

toronto_latitude = 43.651070
toronto_longitude = -79.347015

map_toronto = folium.Map(location=[toronto_latitude, toronto_longitude], zoom_start=12)

for lat, lng, borough, neighborhood in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Borough'], toronto_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# Requirement already satisfied: folium==0.5.0 in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (0.5.0)
# Requirement already satisfied: requests in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from folium==0.5.0) (2.22.0)
# Requirement already satisfied: six in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from folium==0.5.0) (1.12.0)
# Requirement already satisfied: branca in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from folium==0.5.0) (2.11.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from requests->folium==0.5.0) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from requests->folium==0.5.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from requests->folium==0.5.0) (2019.9.11)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\avani\appdata\local\programs\python\python37-32\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f672ec7e7b0b4612bc0bbd509b55cade%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f672ec7e7b0b4612bc0bbd509b55cade%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f672ec7e7b0b4612bc0bbd509b55cade%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f672ec7e7b0b4612bc0bbd509b55cade%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.65107%2C-79.347015%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Foursquare credentials

# %%
CLIENT_ID = 'POMDLLVBQ3BDVRBS5WR1WZHQT0DLR0BZ04ZVZSMIEOVLWKXI'      # your Foursquare ID
CLIENT_SECRET = 'MV0ZPQIDKQFTENO3CBEP2G15QA5NZP3VVWZ5MG3JFGTO5BCE'  # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: POMDLLVBQ3BDVRBS5WR1WZHQT0DLR0BZ04ZVZSMIEOVLWKXI
# CLIENT_SECRET:MV0ZPQIDKQFTENO3CBEP2G15QA5NZP3VVWZ5MG3JFGTO5BCE

# %% [markdown]
# #### Function to get venues near a certain lat/long

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### Calling above function to get nearby venues in Toronto

# %%
toronto_venues = getNearbyVenues(names=toronto_df['Neighborhood'],
                                   latitudes=toronto_df['Latitude'],
                                   longitudes=toronto_df['Longitude']
                                  )

toronto_venues.head()
# Out:
# The Danforth  East
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Rosedale
# St. James Town, Cabbagetown
# Church and Wellesley
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North & West
# The Annex, North Midtown, Yorkville
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# First Canadian Place, Underground city
# Christie
# Dufferin, Dovercourt Village
# Little Portugal, Trinity
# Brockton, Parkdale Village, Exhibition Place
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
#          Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  The Danforth  East              43.685347              -79.338106
# 1  The Danforth  East              43.685347              -79.338106
# 2  The Danforth  East              43.685347              -79.338106
# 3       Lawrence Park              43.728020              -79.388790
# 4       Lawrence Park              43.728020              -79.388790
#
#                   Venue  Venue Latitude  Venue Longitude     Venue Category
# 0              The Path       43.683923       -79.335007               Park
# 1   Donlands & Mortimer       43.687680       -79.340100       Intersection
# 2    Sammon Convenience       43.686951       -79.335007  Convenience Store
# 3  Lawrence Park Ravine       43.726963       -79.394382               Park
# 4       HYC Design Inc.       43.726793       -79.391681   Business Service

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

#add neighborhood column back to dataframe
toronto_onehot['neighborhood'] = toronto_venues['Neighborhood'] 

#move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()

toronto_grouped = toronto_onehot.groupby('neighborhood').mean().reset_index()
toronto_grouped.head()
# Out:
#                                         neighborhood   Airport  \
# 0                                        Berczy Park  0.000000
# 1       Brockton, Parkdale Village, Exhibition Place  0.000000
# 2  CN Tower, King and Spadina, Railway Lands, Har...  0.071429
# 3                                 Central Bay Street  0.000000
# 4                                           Christie  0.000000
#
#    Airport Food Court  Airport Lounge  Airport Service  Airport Terminal  \
# 0            0.000000        0.000000         0.000000          0.000000
# 1            0.000000        0.000000         0.000000          0.000000
# 2            0.071429        0.142857         0.214286          0.142857
# 3            0.000000        0.000000         0.000000          0.000000
# 4            0.000000        0.000000         0.000000          0.000000
#
#    American Restaurant  Antique Shop  Aquarium  Art Gallery  ...  \
# 0                  0.0           0.0       0.0     0.017241  ...
# 1                  0.0           0.0       0.0     0.000000  ...
# 2                  0.0           0.0       0.0     0.000000  ...
# 3                  0.0           0.0       0.0     0.000000  ...
# 4                  0.0           0.0       0.0     0.000000  ...
#
#    Toy / Game Store  Trail  Train Station  Vegetarian / Vegan Restaurant  \
# 0               0.0    0.0            0.0                       0.017241
# 1               0.0    0.0            0.0                       0.000000
# 2               0.0    0.0            0.0                       0.000000
# 3               0.0    0.0            0.0                       0.015385
# 4               0.0    0.0            0.0                       0.000000
#
#    Video Game Store  Vietnamese Restaurant  Wine Bar  Wine Shop  \
# 0               0.0                    0.0  0.000000        0.0
# 1               0.0                    0.0  0.000000        0.0
# 2               0.0                    0.0  0.000000        0.0
# 3               0.0                    0.0  0.015385        0.0
# 4               0.0                    0.0  0.000000        0.0
#
#    Women's Store  Yoga Studio
# 0            0.0     0.000000
# 1            0.0     0.000000
# 2            0.0     0.000000
# 3            0.0     0.015385
# 4            0.0     0.000000
#
# [5 rows x 217 columns]

# %%
import numpy as np
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]


num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['neighborhood'] = toronto_grouped['neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 3                                 Central Bay Street           Coffee Shop
# 4                                           Christie         Grocery Store
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Bakery          Cocktail Bar              Pharmacy
# 1           Coffee Shop        Breakfast Spot             Pet Store
# 2        Airport Lounge      Airport Terminal               Airport
# 3        Sandwich Place    Italian Restaurant                  Café
# 4                  Café                  Park            Restaurant
#
#   5th Most Common Venue   6th Most Common Venue 7th Most Common Venue  \
# 0           Cheese Shop                     Pub            Restaurant
# 1                   Bar  Furniture / Home Store          Intersection
# 2      Sculpture Garden           Boat or Ferry   Rental Car Location
# 3   Japanese Restaurant         Bubble Tea Shop           Salad Place
# 4             Nightclub             Candy Store            Baby Store
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Italian Restaurant        Farmers Market               Beer Bar
# 1    Italian Restaurant             Nightclub      Convenience Store
# 2       Harbor / Marina    Airport Food Court                    Bar
# 3          Burger Joint            Restaurant  Portuguese Restaurant
# 4           Coffee Shop    Italian Restaurant    Distribution Center

# %% [markdown]
# ## Clustering Neighborhoods

# %%
from sklearn.cluster import KMeans

#set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]


# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_df

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   PostalCode                Borough        Neighborhood   Latitude  Longitude  \
# 0        M4J  East YorkEast Toronto  The Danforth  East  43.685347 -79.338106
# 1        M4N        Central Toronto       Lawrence Park  43.728020 -79.388790
# 2        M4P        Central Toronto    Davisville North  43.712751 -79.390197
# 3        M4R        Central Toronto  North Toronto West  43.715383 -79.405678
# 4        M4S        Central Toronto          Davisville  43.704324 -79.388790
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               3     Convenience Store                  Park
# 1               4                  Park              Bus Line
# 2               0                 Hotel                   Gym
# 3               0           Coffee Shop        Clothing Store
# 4               0        Sandwich Place           Pizza Place
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0          Intersection           Yoga Studio   Distribution Center
# 1           Swim School      Business Service           Yoga Studio
# 2  Gym / Fitness Center            Playground      Department Store
# 3           Yoga Studio                 Diner                   Spa
# 4          Dessert Shop           Coffee Shop    Italian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0    Falafel Restaurant           Event Space  Ethiopian Restaurant
# 1               Dog Run           Event Space  Ethiopian Restaurant
# 2        Sandwich Place        Breakfast Spot     Food & Drink Shop
# 3    Seafood Restaurant   Sporting Goods Shop  Fast Food Restaurant
# 4                  Café      Sushi Restaurant                   Gym
#
#   9th Most Common Venue 10th Most Common Venue
# 0           Escape Room      Electronics Store
# 1           Escape Room      Electronics Store
# 2                  Park         General Travel
# 3    Mexican Restaurant     Salon / Barbershop
# 4     Indian Restaurant         Farmers Market

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ### Creating map

# %%
map_clusters = folium.Map(location=[toronto_latitude, toronto_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
toronto_merged.head()

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 2    Central Toronto               0                 Hotel
# 3    Central Toronto               0           Coffee Shop
# 4    Central Toronto               0        Sandwich Place
# 6    Central Toronto               0           Coffee Shop
# 8   Downtown Toronto               0           Coffee Shop
# 9   Downtown Toronto               0           Coffee Shop
# 10  Downtown Toronto               0           Coffee Shop
# 11  Downtown Toronto               0           Coffee Shop
# 12  Downtown Toronto               0           Coffee Shop
# 13  Downtown Toronto               0           Coffee Shop
# 14  Downtown Toronto               0           Coffee Shop
# 15  Downtown Toronto               0           Coffee Shop
# 16  Downtown Toronto               0           Coffee Shop
# 17  Downtown Toronto               0           Coffee Shop
# 18  Downtown Toronto               0           Coffee Shop
# 21   Central Toronto               0           Coffee Shop
# 22  Downtown Toronto               0                  Café
# 23  Downtown Toronto               0                   Bar
# 24  Downtown Toronto               0       Airport Service
# 25  Downtown Toronto               0           Coffee Shop
# 26  Downtown Toronto               0         Grocery Store
# 27      West Toronto               0              Pharmacy
# 28      West Toronto               0                   Bar
# 29      West Toronto               0                  Café
# 30      West Toronto               0                  Café
# 31      West Toronto               0             Gift Shop
# 32      West Toronto               0           Coffee Shop
#
#    2nd Most Common Venue      3rd Most Common Venue  4th Most Common Venue  \
# 2                    Gym       Gym / Fitness Center             Playground
# 3         Clothing Store                Yoga Studio                  Diner
# 4            Pizza Place               Dessert Shop            Coffee Shop
# 6    Fried Chicken Joint                        Pub             Restaurant
# 8            Pizza Place                       Café                    Pub
# 9    Japanese Restaurant           Sushi Restaurant                Gay Bar
# 10                  Café                        Pub                 Bakery
# 11        Clothing Store            Bubble Tea Shop                   Café
# 12                  Café               Cocktail Bar             Restaurant
# 13                Bakery               Cocktail Bar               Pharmacy
# 14        Sandwich Place         Italian Restaurant                   Café
# 15                  Café                 Restaurant        Thai Restaurant
# 16              Aquarium                       Café                  Hotel
# 17                  Café                      Hotel             Restaurant
# 18            Restaurant                       Café                  Hotel
# 21                  Café             Sandwich Place           Liquor Store
# 22             Bookstore        Japanese Restaurant                    Bar
# 23                  Café                Coffee Shop                 Bakery
# 24        Airport Lounge           Airport Terminal                Airport
# 25                  Café                      Hotel                    Gym
# 26                  Café                       Park             Restaurant
# 27                Bakery  Middle Eastern Restaurant            Music Venue
# 28                  Café                 Restaurant  Vietnamese Restaurant
# 29           Coffee Shop             Breakfast Spot              Pet Store
# 30    Mexican Restaurant            Thai Restaurant              Bookstore
# 31        Breakfast Spot                  Bookstore           Dessert Shop
# 32                  Café           Sushi Restaurant     Italian Restaurant
#
#             5th Most Common Venue   6th Most Common Venue  \
# 2                Department Store          Sandwich Place
# 3                             Spa      Seafood Restaurant
# 4              Italian Restaurant                    Café
# 6                     Supermarket        Sushi Restaurant
# 8              Italian Restaurant                  Bakery
# 9                      Restaurant             Yoga Studio
# 10                           Park          Breakfast Spot
# 11             Italian Restaurant     Japanese Restaurant
# 12                       Beer Bar     Japanese Restaurant
# 13                    Cheese Shop                     Pub
# 14            Japanese Restaurant         Bubble Tea Shop
# 15                 Clothing Store           Deli / Bodega
# 16                     Restaurant                 Brewery
# 17            Japanese Restaurant                  Bakery
# 18                            Gym      Seafood Restaurant
# 21      Middle Eastern Restaurant       Indian Restaurant
# 22                         Bakery             Yoga Studio
# 23            Arts & Crafts Store   Vietnamese Restaurant
# 24               Sculpture Garden           Boat or Ferry
# 25            Japanese Restaurant              Restaurant
# 26                      Nightclub             Candy Store
# 27                           Park                    Café
# 28  Vegetarian / Vegan Restaurant             Coffee Shop
# 29                            Bar  Furniture / Home Store
# 30                          Diner    Fast Food Restaurant
# 31    Eastern European Restaurant                 Dog Run
# 32                            Pub           Burrito Place
#
#             7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 2                  Breakfast Spot     Food & Drink Shop                  Park
# 3             Sporting Goods Shop  Fast Food Restaurant    Mexican Restaurant
# 4                Sushi Restaurant                   Gym     Indian Restaurant
# 6                            Bank          Liquor Store    Light Rail Station
# 8              Chinese Restaurant            Restaurant          Liquor Store
# 9                             Pub           Pizza Place           Men's Store
# 10                     Restaurant               Theater           Yoga Studio
# 11      Middle Eastern Restaurant        Cosmetics Shop        Lingerie Store
# 12                 Lingerie Store                 Diner      Department Store
# 13                     Restaurant    Italian Restaurant        Farmers Market
# 14                    Salad Place          Burger Joint            Restaurant
# 15                          Hotel                   Gym           Salad Place
# 16                 Scenic Lookout   Fried Chicken Joint                 Plaza
# 17             Seafood Restaurant           Salad Place              Beer Bar
# 18                  Deli / Bodega                Bakery    Italian Restaurant
# 21                            Pub             BBQ Joint            Donut Shop
# 22                   Dessert Shop            Restaurant    Italian Restaurant
# 23  Vegetarian / Vegan Restaurant           Gaming Cafe                  Park
# 24            Rental Car Location       Harbor / Marina    Airport Food Court
# 25                     Steakhouse      Asian Restaurant           Salad Place
# 26                     Baby Store           Coffee Shop    Italian Restaurant
# 27                        Brewery            Smoke Shop           Supermarket
# 28                    Men's Store      Asian Restaurant           Yoga Studio
# 29                   Intersection    Italian Restaurant             Nightclub
# 30      Cajun / Creole Restaurant            Restaurant             Speakeasy
# 31                            Bar    Italian Restaurant            Restaurant
# 32            Indie Movie Theater     Fish & Chips Shop             Bookstore
#
#        10th Most Common Venue
# 2              General Travel
# 3          Salon / Barbershop
# 4              Farmers Market
# 6                 Pizza Place
# 8                 Snack Place
# 9    Mediterranean Restaurant
# 10             Cosmetics Shop
# 11                      Diner
# 12                     Bakery
# 13                   Beer Bar
# 14      Portuguese Restaurant
# 15                        Bar
# 16         Italian Restaurant
# 17           Sushi Restaurant
# 18        Japanese Restaurant
# 21             History Museum
# 22                 Beer Store
# 23              Grocery Store
# 24                        Bar
# 25         Seafood Restaurant
# 26        Distribution Center
# 27                        Bar
# 28               Cupcake Shop
# 29          Convenience Store
# 30                Flea Market
# 31              Movie Theater
# 32  Latin American Restaurant

# %% [markdown]
# ### Clustering

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 5    Central Toronto               1            Playground
# 7   Downtown Toronto               1                  Park
# 20   Central Toronto               1                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5                   Park          Tennis Court           Yoga Studio
# 7             Playground                 Trail           Yoga Studio
# 20                 Trail         Jewelry Store      Sushi Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5         Discount Store           Event Space  Ethiopian Restaurant
# 7         Discount Store           Event Space  Ethiopian Restaurant
# 20           Yoga Studio   Distribution Center           Event Space
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 5            Escape Room     Electronics Store  Eastern European Restaurant
# 7            Escape Room     Electronics Store  Eastern European Restaurant
# 20  Ethiopian Restaurant           Escape Room            Electronics Store

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 19  Central Toronto               2                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 19  Fast Food Restaurant           Yoga Studio   Distribution Center
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 19    Falafel Restaurant           Event Space  Ethiopian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 19           Escape Room     Electronics Store  Eastern European Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                  Borough  Cluster Labels 1st Most Common Venue  \
# 0  East YorkEast Toronto               3     Convenience Store
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Park          Intersection           Yoga Studio
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Distribution Center    Falafel Restaurant           Event Space
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0  Ethiopian Restaurant           Escape Room      Electronics Store

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#            Borough  Cluster Labels 1st Most Common Venue  \
# 1  Central Toronto               4                  Park
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1              Bus Line           Swim School      Business Service
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1           Yoga Studio               Dog Run           Event Space
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1  Ethiopian Restaurant           Escape Room      Electronics Store
